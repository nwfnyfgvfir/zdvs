# %%
# 1. 克隆代码仓库到可写目录
# !git clone https://github.com/nwfnyfgvfir/SAM-VMNet.git /kaggle/working/SAM-VMNet
# !mkdir -p /kaggle/working/SAM-VMNet/data/vessel

# 3. 将输入区(只读)的数据和权重复制到工作区(可读写)
# 假设您上传的数据集名称分别为 arcade-dataset 和 samvmnet-weights
# !cp -r /kaggle/input/datasets/zxue927/vessel/* /kaggle/working/SAM-VMNet/data/vessel/
# Out:
# Cloning into '/kaggle/working/SAM-VMNet'...
# remote: Enumerating objects: 956, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 956 (delta 6), reused 10 (delta 3), pack-reused 933 (from 1)
# Receiving objects: 100% (956/956), 92.67 MiB | 43.09 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
# !cp -r /kaggle/input/models/zxue927/models/pytorch/default/1/medsam_vit_b.pth /kaggle/working/SAM-VMNet/pre_trained_weights/
# !cp -r /kaggle/input/models/zxue927/models/pytorch/default/1/vmamba_small_e238_ema.pth /kaggle/working/SAM-VMNet/pre_trained_weights/
# !cp -r /kaggle/input/models/zxue927/models/pytorch/default/1/vmamba_tiny_e292.pth /kaggle/working/SAM-VMNet/pre_trained_weights/
# !cp -r /kaggle/input/models/zxue927/branch1model/pytorch/default/1/best-epoch159-loss0.3441.pth /kaggle/working/SAM-VMNet/pre_trained_weights/

# %%
import torch
print("Python version:", "!python --version") # 注意：可以在下一个 Bash cell 运行 !python --version
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: !python --version
# PyTorch version: 2.10.0+cu128
# CUDA version: 12.8

# %%
import torch
import sys
print("Python version:", sys.version.split()[0])
print("PyTorch version:", torch.__version__)
print("CUDA version:", torch.version.cuda)
# Out:
# Python version: 3.12.12
# PyTorch version: 2.10.0+cu128
# CUDA version: 12.8

# %%
import torch
print("Kaggle PyTorch ABI:", torch._C._GLIBCXX_USE_CXX11_ABI)
# Out:
# Kaggle PyTorch ABI: True

# %%
# %%bash
# cd /kaggle/working/SAM-VMNet
#
# # 1. 修复 requirements.txt 里的 Triton 版本锁
# echo "正在修复 requirements.txt..."
# sed -i 's/triton==2.0.0/triton>=2.2.0/g' requirements.txt
#
# # 2. 安装基础依赖
# echo "正在安装 requirements.txt..."
# pip install -r requirements.txt
# Out:
# 正在修复 requirements.txt...
# 正在安装 requirements.txt...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.3/156.3 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.3 MB/s eta 0:00:00
# ...

# %%
# %cd /kaggle/working/SAM-VMNet



# 2. 原汁原味地下载（去掉 -O 参数，保留原合法文件名）
# !wget "https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.6.2.post1/causal_conv1d-1.6.2.post1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl"
# !wget "https://github.com/state-spaces/mamba/releases/download/v2.3.2.post1/mamba_ssm-2.3.2.post1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl"

# 3. 使用通配符直接安装刚才下载的合法文件
# !pip install causal_conv1d*.whl
# !pip install mamba_ssm*.whl
# Out:
# /kaggle/working/SAM-VMNet
# --2026-05-13 11:28:02--  https://github.com/Dao-AILab/causal-conv1d/releases/download/v1.6.2.post1/causal_conv1d-1.6.2.post1+cu12torch2.10cxx11abiTRUE-cp312-cp312-linux_x86_64.whl
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
import os
import cv2
import numpy as np
from pycocotools.coco import COCO

def generate_correct_masks():
    # ================= 配置路径 =================
    json_file = '/kaggle/working/SAM-VMNet/data/vessel/test/annotations/test.json'   
    mask_output_dir = '/kaggle/working/SAM-VMNet/data/vessel/test/masks'
    os.makedirs(mask_output_dir, exist_ok=True)
    # ============================================
    
    print(f"正在读取标注文件: {json_file} ...")
    coco = COCO(json_file)
    img_ids = coco.getImgIds()
    
    # 定义形态学“膨胀”的核（3x3）
    # 它的作用非常温和：只让白色的血管向外胖 1 个像素，刚好能连上微小的断点
    kernel = np.ones((3, 3), np.uint8)

    print(f"共发现 {len(img_ids)} 张有标注的图片。开始生成精准掩码...")

    for img_id in img_ids:
        img_info = coco.loadImgs(img_id)[0]
        file_name = img_info['file_name']
        width = img_info['width']
        height = img_info['height']
        
        mask_canvas = np.zeros((height, width), dtype=np.uint8)
        
        ann_ids = coco.getAnnIds(imgIds=img_id)
        anns = coco.loadAnns(ann_ids)
        
        for ann in anns:
            # 【核心修复】绝对不自己画！只用官方 API 渲染真实的像素级掩码
            pixel_mask = coco.annToMask(ann)
            mask_canvas = np.maximum(mask_canvas, pixel_mask)
                
        # 将 0和1 转换为 0和255(黑白)
        mask_canvas = mask_canvas * 255
        
        # 【修复断连】进行一次轻微的膨胀操作，把相邻的断点“挤”在一起
        mask_canvas = cv2.dilate(mask_canvas, kernel, iterations=1)
        
        save_path = os.path.join(mask_output_dir, file_name)
        cv2.imwrite(save_path, mask_canvas)
        
    print("✅ 纯净版掩码生成完毕！它们已保存在:", mask_output_dir)

if __name__ == '__main__':
    generate_correct_masks()
# Out:
# 正在读取标注文件: /kaggle/working/SAM-VMNet/data/vessel/test/annotations/test.json ...
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# 共发现 300 张有标注的图片。开始生成精准掩码...
# ✅ 纯净版掩码生成完毕！它们已保存在: /kaggle/working/SAM-VMNet/data/vessel/test/masks

# %%
# %%bash
# cd /kaggle/working/SAM-VMNet
#
# # 1. 修复核心模型加载机制 (models/vmunet/vmunet.py)
# sed -i 's/torch.load(self.load_ckpt_path)/torch.load(self.load_ckpt_path, weights_only=False)/g' models/vmunet/vmunet.py
#
# # 2. 修复训练脚本中的断点续训和测试加载 (train_branch1.py 等)
# sed -i "s/map_location=torch.device('cpu')/map_location=torch.device('cpu'), weights_only=False/g" train_branch1.py
#
# # 3. 预防性修复后续可能会用到的 Branch2 脚本
# sed -i "s/map_location=torch.device('cpu')/map_location=torch.device('cpu'), weights_only=False/g" train_branch2.py 2>/dev/null
# sed -i "s/map_location=torch.device('cpu')/map_location=torch.device('cpu'), weights_only=False/g" test_branch2.py 2>/dev/null
# sed -i "s/torch.load(config.medsam_path)/torch.load(config.medsam_path, weights_only=False)/g" models/medsam/segment_anything/build_sam.py 2>/dev/null
#
# echo "✅ 所有 torch.load 函数已成功解除 weights_only 限制！"
# Out:
# ✅ 所有 torch.load 函数已成功解除 weights_only 限制！

# %%
# 1. 进入您的项目目录 (必须用 % 才能改变全局目录)
# %cd /kaggle/working/SAM-VMNet



# 3. 赋予脚本执行权限（防止 Permission denied）
# !chmod +x train_branch1.sh train_branch2.sh

# 4. 正式运行脚本！(这里以 train.sh 为例)
# !bash train_branch2.sh
# Out:
# /kaggle/working/SAM-VMNet
# #----------GPU init----------#
# #----------Generating Branch1 pred_masks----------#
# Total model_dict: 222, Total pretrained_dict: 212, update: 117
# ...
